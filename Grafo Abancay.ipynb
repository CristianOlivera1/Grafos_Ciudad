# %%
import networkx as nx
import folium
# ~~@autor CristianOlivera1~~
grafo = nx.Graph()# Crear un grafo vacío

# Agregar vértices con etiquetas
vertices = ['sevicentro_panamericano','capilla_illanya','circuito_manejo_illanya','iep_amauta','hospital_ESSALUD','ABANCAY','ciudad_de_dios','sinchi_roca','facultad_medicina_veterinaria','parque_imperio','hospital_guillermo_diaz','terminal_terrestre','coliseo','plaza_armas',
            'parque_santa_rosa','americas','UTEA','MIGUEL_GRAU','ESTADIO_CONDEBAMBA','parque_micaela','olivo','cementerio','cementerio_puca_puca',#abancay
            'estadio_olivo','parque_caida','mirador_taraccasa','comunidad_de_asilo','atumpata_baja','condado_centro_poblado','comunidad_quisapata','crus_blanca_cima_quisapata','molinopata','capilla_trujipata','ccacsa','quinta_piscigranja_rinconmayo','planta_tratamiento',
            'laguna_rontoccocha','quinta_piquisiqui','hacienda_san_gabriel','casa_pachachaca','jardines_recuerdo','puente_pachachaca','raqac_huayqo_huayllabamba','huayllabamba','nevado_ampay','qelloyaku','tuneles_carcatera','cascada_karkatera','baños_termales_santo_tomas',#abancay
            'ie_sirca', 'cs_sirca', 'plaza_sirca', 'cafeteria_sirca', 'sirca','uncabamba','fundo_atumpata_contreras','ocobamba'#circa
            'mirador_cachora','escuela_cachora','casanostra_choquequirao','plaza_san_pedro_de_cachora','inca_dream_choquequirao','hacienda_la_colmena','capuliyoc_hotel','chiquisca_camping','chikis',#cachora
            'Centro_de_salud_Lucuchanga', 'MCP_Chalhuani', 'Plaza_Ocrabamba','Plaza_Pichirhua', 'Finca_Nuñes_Allca','Peaje_paty_cruz','Chusña','Totora_Pampa','Auquibamba','Puente_Sahuinto','Cotarma','Grifo_PetroMar','puente_pacpachaca','RumiChaca',#pichirhua
            'Marccopucro2','Puncutuy2','Salinera','Totoraqui','Pajonal','Pataquisqayoc','Ccallasuque','Tacmara','Karquequi','Ccarabamba','Huanchulla','Umacalli','Chaquiccocha','Uchubamba','Sorcca','Occopata','Ccoya','Huanusqui','Chihuanpata','Lambramaqui','Pujyupampa',
            'Ccollca','Huanipaca','Kerapata','Ccotaqui','Mitanay','Pacobamba','Rosaspata','Puncutuy','Sorcca','Ichu Orcco','kiuñalla','Huayllani','Lachirhuay','Suyunacuy','Macayhuani','San Ignacio','Huamanay','Soncotoy','Sorcca','Inkahuasi','Marccopucro','Yaritayoc',
            'Mutcapata','Muñaqui','Sicllabamba','Mayhuay','Tambobamba','Huaccompa','Siqllabamba','Murcoy','Layampampa','Quisuar','Pariguana','Truja','Ronccohuasi','Chanchayllo','Cutabambas','Potrero','Aujello','Parhuani','Livirco','Chaquicachayoc','Marccopucro'#Huanipaca
            'Huanjor','Sahuinto','Intibamba','Matara','Atocsayco','Chalhuapuquio','Ico','Marabamba','Choccemaray','Suncho','Huachacpampa','Huayrapampa','Huancachaca','Santa Isabel de Caype','Chirhuay','Siusay','Soccospampa','Paccaypata','Huaycaja','Toctoja','Urpipampa',
            'Pichinacucho','Sima','Itunes','Lambrama','Coscopata','Atancama','Pichiuca','Marjune',#lambrama
            'Casinchihua', 'Casinchia' ,'Chacoche', 'Anchicha', 'Chamaca','restaurant_Apasanca','estadio_maucacalle','grifo_pilotos','polleria_la_madrina','colegio_micaela_bastidas','IE_Edgar_Valer_Pinto','plaza_de_armas_de_Tamburco','IE_Valer_Pinto','VIVERO_Tarpuy_Andino',
            'complejo_deportivo_maucacalle','Industria_Tambo_Grande','vivero_tarpuy_andina','Sahuanay_Tamburco','Santuario_ecologico_del_Ampay','Santuario_Nacional_de_Ampay','centro_comercial_virgen_del_rosario','jardin_de_Bancapata','Establo_Don_Nestor_Peña','kerapata',
            'grifo_santa_martha','Universidad_Nacional_Micaela_Bastidas_de_Apurimac','Hotel_amankay','Puente_Vronicayoc','quinta_victoria','picchu_wasi_hostel','interoceanica_Nazca_Cuzco','SOS_km_799','3S','capilla_del_sr_calvario_soccllaccasa','Aerodromo_de_Abancay','SOS_KM_809',#tamburco
            'Ramal De Cachora','Puente Kunyac','Trancapata Alta','Rosapata','Antacirca','Tastahuayco','Ccecceray','Totoray','Sayhuite','Orccoruro','Ccoropampa', 'Alameda','San Juan De Dios', 'Pisonaypata', 'Trancapata Baja', 'Huayllapucro', 'Asmayacu', 'Lucmos', 'Curahuasi',
            'Ccochua', 'Puca Puca', 'Ccarhua', 'Ccollo', 'Lahuane', 'Trigo Orcco', 'Pucuta', 'Ccapacca', 'Ccollpa', 'Choquemarca', 'Matibamba', 'Vista ALlegre', 'Progreso Larata', 'Carmen', 'Vacas']#Curahuasi
for v in vertices:
    grafo.add_node(v)

# Agregar aristas con pesos
aristas = [('sevicentro_panamericano', 'capilla_illanya',0.469 ),('capilla_illanya', 'circuito_manejo_illanya',0.277 ),('circuito_manejo_illanya', 'ciudad_de_dios',1 ),('circuito_manejo_illanya', 'iep_amauta',0.343 ),('ciudad_de_dios', 'sinchi_roca',0.562 ),
          ('sinchi_roca','facultad_medicina_veterinaria',0.700 ),('facultad_medicina_veterinaria', 'parque_imperio',0.510 ),('parque_imperio', 'hospital_guillermo_diaz', 0.310),('parque_imperio', 'terminal_terrestre',0.350 ),('iep_amauta', 'hospital_ESSALUD',0.640 ),('iep_amauta', 'molinopata',2 ),
          ('molinopata', 'capilla_trujipata',1.17 ),('molinopata', 'ABANCAY',2 ),('capilla_trujipata', 'ccacsa',1.25 ),('hospital_ESSALUD', 'ABANCAY',0.542 ),('ABANCAY', 'terminal_terrestre',0.815 ),('ABANCAY', 'UTEA',1),('terminal_terrestre', 'coliseo', 0.307),
          ('coliseo', 'parque_santa_rosa',0.230 ),('parque_santa_rosa', 'olivo',0.190 ),('olivo', 'estadio_olivo', 0.200),('estadio_olivo', 'UTEA',0.220 ),('estadio_olivo', 'americas',0.210 ),('americas', 'parque_santa_rosa', 0.390),('UTEA', 'cementerio_puca_puca',0.500 ),
          ('UTEA', 'MIGUEL_GRAU', 0.600),('olivo', 'parque_caida', 0.400),('parque_caida', 'MIGUEL_GRAU', 0.200),#abancay
          ('Ccoya', 'cascada_karkatera',5 ), ('terminal_terrestre', 'plaza_armas', 0.750),('plaza_armas', 'parque_micaela', 0.480),('parque_micaela', 'ESTADIO_CONDEBAMBA',0.400 ),('ccacsa', 'tuneles_carcatera', 9), ('parque_micaela', 'cementerio',0.410 ),
          ('ESTADIO_CONDEBAMBA', 'mirador_taraccasa',1.3 ),('mirador_taraccasa', 'comunidad_de_asilo',2 ),('cementerio', 'atumpata_baja',2.6 ),('atumpata_baja', 'condado_centro_poblado', 2),('condado_centro_poblado', 'comunidad_quisapata',1.4 ),('comunidad_quisapata', 'crus_blanca_cima_quisapata',0.807 ),
          ('sevicentro_panamericano', 'quinta_piquisiqui',1.6 ),('quinta_piquisiqui', 'hacienda_san_gabriel',1 ),('hacienda_san_gabriel', 'casa_pachachaca',2),('casa_pachachaca', 'jardines_recuerdo', 0.545),('jardines_recuerdo', 'puente_pachachaca',0.424 ),('puente_pachachaca', 'ccacsa',4 ),
          ('ccacsa', 'huayllabamba',1.68 ),('huayllabamba', 'raqac_huayqo_huayllabamba',4.5 ),('raqac_huayqo_huayllabamba', 'nevado_ampay',4 ),('nevado_ampay', 'qelloyaku', 2),('qelloyaku', 'cascada_karkatera',1.8 ),('qelloyaku', 'tuneles_carcatera',2 ),
          ('tuneles_carcatera', 'cascada_karkatera',2 ),('puente_pachachaca', 'baños_termales_santo_tomas',1.5 ),('atumpata_baja', 'quinta_piscigranja_rinconmayo',1.2 ),('quinta_piscigranja_rinconmayo', 'planta_tratamiento',1.16 ),('planta_tratamiento', 'laguna_rontoccocha',6.33 ),#abancay
          ('ie_sirca', 'sirca', 0.202), ('sirca', 'cs_sirca', 0.40), ('cs_sirca', 'plaza_sirca', 0.113), ('plaza_sirca', 'cafeteria_sirca',0.60), ('ie_sirca', 'uncabamba',3.6), ('uncabamba', 'fundo_atumpata_contreras',2.79), ('ocobamba', 'fundo_atumpata_contreras',5.49),#circa
          ('escuela_cachora', 'mirador_cachora', 1),('mirador_cachora', 'casanostra_choquequirao', 5.5),('casanostra_choquequirao', 'chikis', 19.3),('casanostra_choquequirao', 'plaza_san_pedro_de_cachora', 0.295),('casanostra_choquequirao', 'hacienda_la_colmena', 5.2),
          ('hacienda_la_colmena', 'virgen_carmen', 0.660),('hacienda_la_colmena', 'capuliyoc_hotel', 6.1),('capuliyoc_hotel', 'chiquisca_camping', 6.9),#cachora
          ('Plaza_Ocrabamba', 'Plaza_Pichirhua', 0.140), ('Plaza_Pichirhua', 'Finca_Nuñes_Allca', 1), ('Finca_Nuñes_Allca', 'Peaje_paty_cruz', 3), ('Peaje_paty_cruz', 'Grifo_PetroMar', 6.3), ('Grifo_PetroMar', 'MCP_Chalhuani', 13.5), ('Grifo_PetroMar', 'puente_pacpachaca', 12.3),
          ('puente_pacpachaca', 'Cotarma', 3.4),('Cotarma', 'Centro_de_salud_Lucuchanga', 10), ('puente_pacpachaca', 'Centro_de_salud_Lucuchanga', 10), ('puente_pacpachaca', 'Puente_Sahuinto', 13.7), ('Puente_Sahuinto', 'Auquibamba', 10.2), #pichirhua
          ('Livirco','Chaquicachayoc',1),('Parhuani','Livirco',1),('Quisuar','Parhuani',3),('Quisuar','Cutabambas',3),('Layampampa','Pariguana',1),('Layampampa','Quisuar',1),('Murcoy','Layampampa',2),('Siqllabamba','Murcoy',1),('Huaccompa','Siqllabamba',1),('Huanipaca','Huaccompa',2),
          ('San Pedro','Inkahuasi',5),('Mayhuay','Tambobamba',2),('Sicllabamba','Mayhuay',2),('Muñaqui','Sicllabamba',1),('Mutcapata','Muñaqui',1),('Yaritayoc','Mutcapata',1),('Marccopucro','Yaritayoc',1),('Huanipaca','Marccopucro',1),('San Francisco','Santa Isabel',1),
          ('Mayocc','San Francisco',1),('San Pedro','Mayocc',1),('Tambobamba','San Pedro',1),('Puncutuy','Tambobamba',1),('San Ignacio','Inkahuasi',3),('Kiuñalla','Humanay',3),('Humanay','San Ignacio',1),('Arriendo','Puncutuy2',1),('Suyunacuy','Macayhuani',1),('Huayllani','Lacchirhuay',1),
          ('Kiuñalla','Huayllani',1),('Kiuñalla','Suyunacuy',1),('Kiuñalla','Soncotoy',1),('Ichu Orcco','Kiuñalla',2),('Puncutuy2','Ichu Orcco',2),('Puncutuy','Arriendo',1),('Rosaspata','Puncutuy',1),('Pacobamba','Rosaspata',2),('Mitanay','Pacobamba',1),('Kerapata','Mitanay',1),
          ('Huanipaca','Kerapata',1),('Ccollca','Huanipaca',1),('Pujyupampa','Ccollca',1),('Lambramaqui','Pujyupampa',1),('Chihuampata','Lambramaqui',2),('Huanusqui','Chihuampata',2),('Uchunccoy','Huanusqui',1),('Sorcca','Uchunccoy',3),('Totoraqui','Salinera',2),('Pajonal','Totoraqui',1),
          ('Pataquisqayoc','Pajonal',2),('Ccallasuque','Pataquisqayoc',2),('Tacmara','Pataquisqayoc',2),('Karquequi','Tacmara',2),('Ccarabamba','Karquequi',2),('Huanchulla','Tacmara',4),('Umacalli','Huanchulla',1),('Chaquiccocha','Umacalli',1),('Uchubamba','Chaquiccocha',1),
          ('Sorcca','Umacalli',1),('Occopata','Sorcca',1),('Ccoya','Occopata',1),#Huanipaca
          ('Intibamba','Matara',1),('Matara','Atocsayco',1),('Atocsayco','Chalhuapuquio',1),('Chalhuapuquio','Ico',2),('Ico','Marabamba',1),('Marabamba','Choccemaray',2),('Choccemaray','Suncho',3),('Suncho','Huachacpampa',1),('Huachacpampa','Huayrapampa',1),('Suncho','Huancachaca',1),
          ('Suncho','Santa Isabel de Caype',4),('Huancachaca','Chirhuay',3),('Chirhuay','Siusay',1),('Chirhuay','Soccospampa',2),('Soccospampa','Paccaypata',2),('Paccaypata','Huaycaja',1),('Huaycaja','Toctoja',1),('Toctoja','Urpipampa',1),('Urpipampa','Pichinacucho',1),
          ('Pichinacucho','Sima',1),('Sima','Itunes',1),('Itunes','Lambrama',2),('Lambrama','Coscopata',2),('Coscopata','Atancama',1),('Sima','Pichiuca',2),('Pichiuca','Marjune',4),
          ('Huanjor','Sahuinto',1),('Huanjor','Intibamba',9),('Casinchihua','Casinchia', 3.4),('Casinchia','Chacoche', 10.1),('Chacoche','Anchicha', 8.9),('Industria_Tambo_Grande','jardin_de_Bancapata',1),('jardin_de_Bancapata','Establo_Don_Nestor_Peña',2.3),
          ('Establo_Don_Nestor_Peña','kerapata',1.550),('el_arco','estadio_maucacalle',1.500),('estadio_maucacalle','complejo_deportivo_maucacalle',1.750),('estadio_maucacalle','VIVERO_Tarpuy_Andino',1.1),('VIVERO_Tarpuy_Andino','Santuario_ecologico_del_Ampay',1.8),
          ('Santuario_ecologico_del_Ampay','Santuario_Nacional_de_Ampay',3.8),('Santuario_ecologico_del_Ampay','Sahuanay_Tamburco',1.9),('Sahuanay_Tamburco','centro_comercial_virgen_del_rosario',1.600),('centro_comercial_virgen_del_rosario','Industria_Tambo_Grande',1.650),
          ('Industria_Tambo_Grande','plaza_de_armas_de_Tamburco',1.300),('plaza_de_armas_de_Tamburco','colegio_micaela_bastidas',1.180),('colegio_micaela_bastidas','IE_Edgar_Valer_Pinto',1.260),('grifo_pilotos','polleria_la_madrina',1.230),('polleria_la_madrina','grifo_santa_martha',1.750),
          ('grifo_santa_martha','Universidad_Nacional_Micaela_Bastidas_de_Apurimac',1.800),('Universidad_Nacional_Micaela_Bastidas_de_Apurimac','Hotel_amankay',1.750),('Hotel_amankay','quinta_victoria',1.7),('quinta_victoria','picchu_wasi_hostel',4.8),
          ('picchu_wasi_hostel','interoceanica_Nazca_Cuzco',9.8),('interoceanica_Nazca_Cuzco','SOS_km_799',3.8),('SOS_km_799','3S',4.1),('3S','capilla_del_sr_calvario_soccllaccasa',2.9),('capilla_del_sr_calvario_soccllaccasa','SOS_KM_809',3.1),('SOS_KM_809','Aerodromo_de_Abancay',2.8),
          ('escuela_cachora','Chaquicachayoc', 4),('escuela_cachora','Ramal De Cachora', 4),('Chaquicachayoc','Ramal De Cachora', 4),('Aerodromo_de_Abancay','Ramal De Cachora', 4),('Ramal De Cachora','Antacirca', 1),('Orccoruro','Ccoropampa', 2),('Puente Kunyac','Ccarhua', 2),
          ('Carmen','Puente Kunyac', 3),('Lucmos','Curahuasi', 1),('Pisonaypata','Lucmos', 2),('Pisonaypata','Huayllapucro', 1),('Huayllapucro','Asmayacu', 1),('Trancapata Baja','Asmayacu', 3),('Trancapata Baja','Huayllapucro', 1),('Trancapata Baja','Pisonaypata', 1),
          ('Alameda','Pisonaypata', 1),('San Juan De Dios','Trancapata Baja', 1),('Vacas','Trancapata Alta', 1),('Trancapata Baja','Trancapata Alta', 1),('Orccoruro','Rosapata', 2),('Antacirca','Tastahuayco', 1),('Tastahuayco','Ccecceray', 2), ('Rosapata','San Juan De Dios', 1),
          ('Ccecceray','Totoray', 3), ('Antacirca','Sayhuite', 1.5), ('Sayhuite','Orccoruro', 3), ('Alameda','San Juan De Dios', 1), ('San Juan De Dios','Vacas', 1), ('Curahuasi','Puca Puca', 1), ('Curahuasi','Ccochua', 2), ('Ccochua','Ccollo', 5), ('Curahuasi','Carmen', 4),
          ('Ccollo','Trigo Orcco', 2), ('Trigo Orcco','Ccapacca', 1), ('Ccapacca','Pucuta', 2), ('Pucuta','Ccollpa', 1), ('Ccollpa','Choquemarca', 1)]
for a in aristas:
    origen, destino, peso = a
    grafo.add_edge(origen, destino, peso=peso)

# Definir las coordenadas de los vértices en el espacio
              'Ramal De Cachora':[-13.542208708768722, -72.80428361650931],'Puente Kunyac':[-13.562818581681144, -72.57530879827546],'Trancapata Alta':[-13.569076285963462, -72.75319289929334],'Rosapata':[-13.556811029832325, -72.76688289407537],'Antacirca':[-13.540435508771933, -72.80030321845224],
              'Tastahuayco':[-13.549457830305874, -72.801107879902],'Ccecceray':[-13.559667975891987, -72.80055544268643],'Totoray':[-13.572319797757046, -72.79415559408584],'Sayhuite':[-13.541030053991962, -72.78565835644608],'Orccoruro':[-13.53934029071969, -72.74851512687646],
              'Ccoropampa':[-13.527479605651557, -72.73176225335526],'Alameda':[-13.554294367190831, -72.7507982274636],'San Juan De Dios':[-13.562531247459663, -72.75514621983872],'Pisonaypata':[-13.55508357498983, -72.73847518570003],'Trancapata Baja':[-13.564153562847501, -72.75116307765444],
              'Huayllapucro':[-13.562693425550782, -72.73589801580675],'Asmayacu':[-13.578921407293414, -72.73113441263804],'Lucmos':[-13.541572442110844, -72.71154357114742],'Curahuasi':[-13.540195601930868, -72.69630862440616],'Ccochua':[-13.566489788152015, -72.70014953379132],
              'Puca Puca':[-13.556216521777422, -72.68618060300409],'Ccarhua':[-13.581424339618575, -72.56118965037737],'Ccollo':[-13.63648214780002, -72.60273170262896],'Lahuane':[-13.683854959349981, -72.6882190657518],'Trigo Orcco':[-13.648159429484014, -72.56187629598958],
              'Pucuta':[-13.676182545330011, -72.49183845632265],'Ccapacca':[-13.634813918365321, -72.54059028589472],'Ccollpa':[-13.702107216707587, -72.50318957456133],'Choquemarca':[-13.704535875161229, -72.53372383102543],'Matibamba':[-13.642487679439252, -72.4451465632114],
              'Vista ALlegre':[-13.673847412957224, -72.45132637259378],'Progreso Larata':[-13.680185575518236, -72.45887947295002],'Carmen':[-13.549718586446245, -72.61577796666143],'Vacas':[-13.571996491723677, -72.76113223804924]}


# Crear un objeto de mapa
mapa = folium.Map(location=[-13.637657802678357, -72.8952090627736], zoom_start=10)

# Agregar aristas al mapa con etiquetas de peso
for origen, destino, attrs in grafo.edges(data=True):
    peso = attrs['peso']
    pos_origen = posiciones[origen]
    pos_destino = posiciones[destino]
    etiqueta = f'Distancia: {peso} KM'
    folium.PolyLine([pos_origen, pos_destino], color='red', weight=2, tooltip=etiqueta).add_to(mapa)


# Agregar nodos al mapa
for v, pos in posiciones.items():
    folium.Marker(location=pos, popup=v).add_to(mapa)

# Mostrar el mapa interactivo
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
from geopy.geocoders import Nominatim
import folium
# Función para obtener coordenadas geográficas a partir de un lugar
def obtener_coordenadas(lugar):
    geolocator = Nominatim(user_agent="my-app")  # Cambia "my-app" por un nombre único
    location = geolocator.geocode(lugar)
    if location is not None:
        return location.latitude, location.longitude
    else:
        return None


# Obtener coordenadas y agregar marcador en el mapa
lugar_buscar = input("Ingrese el lugar a buscar: ")
coordenadas = obtener_coordenadas(lugar_buscar)
if coordenadas is not None:
    folium.Marker(location=coordenadas, popup=lugar_buscar, icon=folium.Icon(color='green')).add_to(mapa)
     # Ajustar el mapa para que se enfoque en el lugar buscado
    mapa.fit_bounds([coordenadas, coordenadas])
else:
    print("No se encontraron coordenadas para el lugar especificado.")

# Mostrar el mapa interactivo
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...
